# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
# !pip install -q langchain-openai langchain-core requests
# Out:
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# tool create

@tool
def multiply(a: int, b: int) -> int:
  """Given 2 numbers a and b this tool returns their product"""
  return a + b

# %%
print(multiply.invoke({'a':3, 'b':4}))
# Out:
# 7

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool binding

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GEMINI_API_KEY")
)

# %%
llm.invoke('hi')
# Out:
# AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f47ee-884b-7a51-8680-3026c07aacca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 241, 'total_tokens': 243, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 231}})

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('Hi how are you')
# Out:
# AIMessage(content="I'm doing well, thank you! How can I help you today?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f47ee-9215-77f0-9487-eea437ed94f1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 16, 'total_tokens': 74, 'input_token_details': {'cache_read': 0}})

# %%
query = HumanMessage('can you multiply 3 with 1000')

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(messages)

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 1000, "a": 3}'}, '__gemini_function_call_thought_signatures__': {'fed3a14d-34be-440c-b3ac-69b05e311f07': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f47ee-9554-7503-8010-8693c0967c0d-0', tool_calls=[{'name': 'multiply', 'args': {'b': 1000, 'a': 3}, 'id': 'fed3a14d-34be-440c-b3ac-69b05e311f07', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 65, 'output_tokens': 96, 'total_tokens': 161, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 75}})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
tool_result
# Out:
# ToolMessage(content='1003', name='multiply', tool_call_id='fed3a14d-34be-440c-b3ac-69b05e311f07')

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 1000, "a": 3}'}, '__gemini_function_call_thought_signatures__': {'fed3a14d-34be-440c-b3ac-69b05e311f07': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f47ee-9554-7503-8010-8693c0967c0d-0', tool_calls=[{'name': 'multiply', 'args': {'b': 1000, 'a': 3}, 'id': 'fed3a14d-34be-440c-b3ac-69b05e311f07', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 65, 'output_tokens': 96, 'total_tokens': 161, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 75}}),
#  ToolMessage(content='1003', name='multiply', tool_call_id='fed3a14d-34be-440c-b3ac-69b05e311f07')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_google_genai\chat_models.py:3234, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3233 try:
# -> 3234     response: GenerateContentResponse = self.client.models.generate_content(
#    3235         **request,
#    3236     )
#    3237 except ClientError as e:
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\models.py:6465, in Models.generate_content(self, model, contents, config)
#    6458     logger.warning(
#    6459         'Tools at indices [%s] are not compatible with automatic function '
#    6460         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   6463         indices_str,
#    6464     )
# -> 6465   return self._generate_content(
#    6466       model=model, contents=contents, config=parsed_config
#    6467   )
#    6469 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    6470     parsed_config
#    6471 )
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\models.py:4916, in Models._generate_content(self, model, contents, config)
#    4914 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4916 response = self._api_client.request(
#    4917     'post', path, request_dict, http_options
#    4918 )
#    4920 if config is not None and getattr(
#    4921     config, 'should_return_http_response', None
#    4922 ):
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\_api_client.py:1618, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1615 http_request = self._build_request(
#    1616     http_method, path, request_dict, http_options
#    1617 )
# -> 1618 response = self._request(http_request, http_options, stream=False)
#    1619 response_body = (
#    1620     response.response_stream[0] if response.response_stream else ''
#    1621 )
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\_api_client.py:1409, in BaseApiClient._request(self, http_request, http_options, stream)
#    1408     retry = tenacity.Retrying(**retry_kwargs)
# -> 1409     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1411 return self._retry(self._request_once, http_request, stream)
#
# File c:\LANGCHAIN\venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\LANGCHAIN\venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\LANGCHAIN\venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\LANGCHAIN\venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\LANGCHAIN\venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient._request_once(self, http_request, stream)
#    1387   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1388 errors.APIError.raise_for_response(response)
#    1389 return HttpResponse(
#    1390     response.headers, response if stream else [response.text]
#    1391 )
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\LANGCHAIN\venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 35.641416483s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '35s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 llm_with_tools.invoke(messages).content
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_core\runnables\base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_google_genai\chat_models.py:2701, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2698         msg = "Tools are already defined.code_execution tool can't be defined"
#    2699         raise ValueError(msg)
# -> 2701 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_google_genai\chat_models.py:3238, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3234     response: GenerateContentResponse = self.client.models.generate_content(
#    3235         **request,
#    3236     )
#    3237 except ClientError as e:
# -> 3238     _handle_client_error(e, request)
#    3240 return _response_to_result(response)
#
# File c:\LANGCHAIN\venv\Lib\site-packages\langchain_google_genai\chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 35.641416483s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '35s'}]}}

# %%
# tool create
from langchain_core.tools import InjectedToolArg
from typing import Annotated

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
  """
  This function fetches the currency conversion factor between a given base currency and a target currency
  """
  url = f'https://v6.exchangerate-api.com/v6/c754eab14ffab33112e380ca/pair/{base_currency}/{target_currency}'

  response = requests.get(url)

  return response.json()

@tool
def convert(base_currency_value: int, conversion_rate: Annotated[float, InjectedToolArg]) -> float:
  """
  given a currency conversion rate this function calculates the target currency value from a given base currency value
  """

  return base_currency_value * conversion_rate

# %%
convert.args
# Out:
# {'base_currency_value': {'title': 'Base Currency Value', 'type': 'integer'}}

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1783555202,
#  'time_last_update_utc': 'Thu, 09 Jul 2026 00:00:02 +0000',
#  'time_next_update_unix': 1783641602,
#  'time_next_update_utc': 'Fri, 10 Jul 2026 00:00:02 +0000',
#  'base_code': 'USD',
#  'target_code': 'INR',
#  'conversion_rate': 95.6063}

# %%
convert.invoke({'base_currency_value':10, 'conversion_rate':85.16})
# Out:
# 851.5999999999999

# %%
# tool binding
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GEMINI_API_KEY")
)

# %%
llm_with_tools = llm.bind_tools([get_conversion_factor, convert])

# %%
messages = [HumanMessage('What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd')]

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd', additional_kwargs={}, response_metadata={})]

# %%
ai_message = llm_with_tools.invoke(messages)

# %%
messages.append(ai_message)

# %%
ai_message.tool_calls
# Out:
# [{'name': 'get_conversion_factor',
#   'args': {'base_currency': 'INR', 'target_currency': 'USD'},
#   'id': 'f31377c3-7815-40b2-9c5b-b94fe0c99a0d',
#   'type': 'tool_call'}]

# %%
import json

for tool_call in ai_message.tool_calls:
  # execute the 1st tool and get the value of conversion rate
  if tool_call['name'] == 'get_conversion_factor':
    tool_message1 = get_conversion_factor.invoke(tool_call)
    # fetch this conversion rate
    conversion_rate = json.loads(tool_message1.content)['conversion_rate']
    # append this tool message to messages list
    messages.append(tool_message1)
  # execute the 2nd tool using the conversion rate from tool 1
  if tool_call['name'] == 'convert':
    # fetch the current arg
    tool_call['args']['conversion_rate'] = conversion_rate
    tool_message2 = convert.invoke(tool_call)
    messages.append(tool_message2)

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_conversion_factor', 'arguments': '{"base_currency": "INR", "target_currency": "USD"}'}, '__gemini_function_call_thought_signatures__': {'f31377c3-7815-40b2-9c5b-b94fe0c99a0d': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4729-5538-7253-85b7-43eb69a0db14-0', tool_calls=[{'name': 'get_conversion_factor', 'args': {'base_currency': 'INR', 'target_currency': 'USD'}, 'id': 'f31377c3-7815-40b2-9c5b-b94fe0c99a0d', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 150, 'output_tokens': 120, 'total_tokens': 270, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 94}}),
#  ToolMessage(content='{"result": "success", "documentation": "https://www.exchangerate-api.com/docs", "terms_of_use": "https://www.exchangerate-api.com/terms", "time_last_update_unix": 1783555202, "time_last_update_utc": "Thu, 09 Jul 2026 00:00:02 +0000", "time_next_update_unix": 1783641602, "time_next_update_utc": "Fri, 10 Jul 2026 00:00:02 +0000", "base_code": "INR", "target_code": "USD", "conversion_rate": 0.01046}', name='get_conversion_factor', tool_call_id='f31377c3-7815-40b2-9c5b-b94fe0c99a0d')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# ''

# %%
from langchain.agents import create_agent

# Step 5: Initialize the Agent ---
agent_executor = create_agent(
    model=llm,
    tools=[get_conversion_factor, convert, multiply],
    system_prompt="You must always use the provided tools for any arithmetic calculation. Never compute math yourself — always call the appropriate tool."
)

# %%
# --- Step 6: Run the Agent ---
user_query = "can u tell me wht is 87 time 45"

response = agent_executor.invoke({"messages": [{"role": "user", "content": user_query}]})
print(response["messages"][-1].content)
# Out:
# 87 multiplied by 45 is 3915.
