# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

from dotenv import load_dotenv
import os

# %%
load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")

print(api_key[:10])
# Out:
# AQ.Ab8RN6L

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7,
    google_api_key=api_key
)

# %%
response = llm.invoke(
    "Suggest one high-demand skill for a computer science student."
)

print(response.content)
# Out:
# **Cloud Computing**
#
# It's foundational, underpins almost all modern software development, data science, and AI/ML, and proficiency in platforms like AWS, Azure, or Google Cloud is highly sought after across various roles. Knowing how to deploy, manage, and scale applications and data in the cloud is an indispensable skill.

# %%
template = """
Give me 3 career skills that are in high demand in {year}.
"""

prompt_template = PromptTemplate.from_template(template)

# %%
formatted_prompt = prompt_template.format(
    year="2026"
)

print(formatted_prompt)
# Out:
# Give me 3 career skills that are in high demand in 2026.

# %%
parser = StrOutputParser()

# %%
chain = prompt_template | llm | parser

# %%
response = chain.invoke(
    {"year": "2026"}
)

print(response)
# Out:
# Here are 3 career skills that are projected to be in high demand in 2026, driven by advancements in AI, automation, and the increasing complexity of the global landscape:
#
# 1.  **AI Fluency & Application (Prompt Engineering, AI-powered Tool Mastery):**
#     *   **Why in Demand:** As AI becomes ubiquitous across all industries, the ability to effectively interact with, leverage, and integrate AI tools (like generative AI, predictive analytics, automation platforms) will be crucial. This isn't about *building* AI for everyone, but understanding its capabilities, limitations, and how to use it to enhance productivity, creativity, and decision-making. Prompt engineering (the art of crafting effective inputs for AI) is a specific, rapidly emerging facet of this skill.
#     *   **What it entails:** Understanding various AI models, knowing how to formulate clear and effective prompts, critically evaluating AI outputs, integrating AI tools into workflows, and identifying opportunities for AI to solve business problems.
#
# 2.  **Complex Problem Solving & Critical Thinking (with an AI Lens):**
#     *   **Why in Demand:** While AI can process vast amounts of data and offer solutions to well-defined problems, humans will be increasingly responsible for identifying the *right* problems, navigating ambiguous situations, making ethical judgments, and interpreting AI-generated insights within a broader strategic context. As routine tasks are automated, the problems left for humans become more intricate and nuanced.
#     *   **What it entails:** Deconstructing complex challenges, analyzing information from diverse sources (including AI outputs), identifying root causes, evaluating multiple solutions, anticipating unintended consequences, and making well-reasoned, strategic decisions that often involve human and ethical considerations.
#
# 3.  **Data Literacy & Strategic Insight:**
#     *   **Why in Demand:** With the explosion of data and AI's ability to generate even more, the skill isn't just about collecting data, but understanding what it means, identifying patterns, extracting actionable insights, and translating those insights into strategic business decisions. This goes beyond basic data analysis; it's about connecting data points to business outcomes and future trends.
#     *   **What it entails:** Interpreting data visualizations, understanding key metrics, identifying biases in data, using data to tell a compelling story, making data-driven recommendations, and understanding how data impacts business strategy and customer experience.
